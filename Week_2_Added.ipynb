# %% [markdown]
# <a href="https://colab.research.google.com/github/yuukionna022/Week2_DataPreprocessing/blob/edit/Week_2_Added.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# In this notebook, we'll explore of Artificial Intelligence Workflow, putting a spotlight on the crucial step of Data Preprocessing.
#
# To make things clear, we'll showcase different types of data. This will help you recognize how various datasets look, where you can find them, and the steps to bring them into your work.
#
# We'll also explore specific libraries tailored for each type of data. This way, you'll get hands-on experience with the tools designed to handle different data formats effectively.
#
# After that, it's time to get hands-on with these datasets. We'll take a closer look at their unique features, understand whether they present classification or regression challenges, and use visualization techniques to make sense of the data's patterns. This practical approach not only hones your skills in data preprocessing but also empowers you to smoothly integrate various libraries and techniques into your AI workflow.

# %% [markdown]
# # **Artificial Intelligence Workflow**

# %% [markdown]
# ![ml-engineering.jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Three Main Steps**:
#
# 1.   Data Preprocessing
# 2.   Model Engineering
# 3.   Model Depolyment
#
# **DATA Preprocessing**
#
#
#
# *   Data Gathering/Integration
# *   Data Exploration
# *   Data Cleaning
# *   Data Transforming
#
#
# **Model Engineering**
#
# *  Model Training
# * Model Evaluation
# * Model Testing
#
#
# **Model Deployment**
#
# * Model Serving
# * Model Performance monitoring

# %% [markdown]
# # **Important Libraries**

# %% [markdown]
# **Libraries required for importing data**:
#
# * Pandas
#
#
# ```
# import pandas as pd
# ```
#
#
#
# **Libraries required for visualizing data**:
#
# * Matplotlib
# * seaborn
#
# ```
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
#
# **Libraries required for handling specific data types:**
#
# * Numerical =>  Numpy
# * Images =>  OpenCV
# * Text =>  NLTK
# * Audio =>  Librosa
# ```
# import numpy as np
# import cv2
# import nltk
# import librosa
# ```

# %% [markdown]
# ## **Installing Libraries**
#
# If you are using Google Colab, some of the libraries are preinstalled .
#
# If you are using Anaconda, almost all the libraries will be pre installed with the package.
#
# If you have downloaded individual Jupyter notebook you will need to install all the required libraries before importing them into code.
#
# Must ensure that you have pip installed in your systems

# %%
# !pip --version
# Out:
# pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %% [markdown]
# Install the library in Python using the pip command in the command prompt (cmd)
#
# You can also install libraries directly from the jupyter notebook by placing "!" before any command.
#
#
# ```
# !pip install package_name
# ```
#
# For the purpose of this notebook, we need to install all the above mentioned libararies, make sure to install them if they are not already installed.

# %%
#!py -m pip install pandas
#!py -m pip install matplotlib
#!py -m pip install seaborn
#!py -m pip install numpy
#!py -m pip install opencv-python
#!py -m pip install nltk
#!py -m pip install librosa

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cv2
import nltk
import librosa

# %% [markdown]
# # **DIFFERENT TYPES OF DATA**

# %% [markdown]
# ## **Tabular Data**
#  * Categorical Labels
#  * Numerical Labels

# %% [markdown]
# ### **Iris Dataset (Categorical Labels)**

# %% [markdown]
# The Iris flower data set consists of 150 samples.
#
# **Three species of Iris:**
#
# * Iris setosa
# * Iris virginica
# * Iris versicolor
#
# **Four features were measured for each sample:**
#
# * Length of the sepals (cm)
# * Width of the sepals (cm)
# * Length of the petals (cm)
# * Width of the petals (cm)
#
# **Problem Statement:**
#
# Distinguish the flowers based on these features.
#
# *Independent variables (Features)*:
# * Length of the sepals
# * Length of the petals
# * Width of the sepals
# * Width of the petals
#
# *Dependent variables (Labels)*:
# * Species of the flower

# %% [markdown]
# **Importing Required libraries**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Loading Dataset**
#
#
# Download the dataset from : https://www.kaggle.com/datasets/uciml/iris
#
# Copy the path of the dataset and paste it in the command *below*

# %%
dataset_1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/IAT 360/0/Iris.csv')

# %% [markdown]
# Preview the dataset

# %%
dataset_1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# When the data is simply analyzed, none of the 6 columns contain null values, which will be a great advantage. The "Species" column will be the target feature and except for the "Id" column, which can be ignored, the other columns are of type "float64".

# %%
dataset_1.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %% [markdown]
# In the describe method, apart from the parameters that are very useful for numerical features (mean, median, 1Q, 3Q etc.), parameters such as "unique, top, freq" that will be used for categorical features are indicated with "include=all".

# %%
dataset_1['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# The 3 different variables of the target feature are distributed in equal numbers.

# %%
fig,(ax1,ax2) = plt.subplots(2,2)
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.SepalLengthCm,ax=ax1[0])
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.SepalWidthCm,ax=ax1[1])
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.PetalWidthCm,ax=ax2[0])
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.PetalLengthCm,ax=ax2[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# Explore the dataset more from : https://www.kaggle.com/datasets/uciml/iris

# %% [markdown]
# ### **House Price Prediction (Numerical Labels)**

# %% [markdown]
# Consisting of 4600 entries for homes in different US cities, this dataset includes 18 different variables that describe various property details such as size and location characteristics.
#
# **Columns**
#
# * date: Date the house was sold
# * price: Sale price of the house (Prediction target)
# * bedrooms: Number of the bedrooms
# * bathrooms: Number the bathrooms
# * sqft_living: Square footage of the home
# * sqft_lot: Square footage of the lot
# * floors: Total floors (levels) in the house
# * waterfront: House which has a view to a waterfront
# * view: Number of views
# * condition: How good the condition is overall
# * sqft_above: Square footage of the house apart from basement
# * sqft_basement: Square footage of the basement
# * yr_built: Building year of the house
# * yr_renovated: Renovation year of the house
# * street: Street where the house is located
# * city: City where the house is located
# * statezip: Zip code of the region where the house is located
# * country: Country where the house is located (USA)
#
# There are 8 categorical (half nominal and half ordinal depending on the measurement level) and 9 discrete variables.
#
# Our ordinal variables, waterfront, view and and renovation year, appear numerically, but we will evaluate them in two categories, 0 and 1, depending on whether they are in the relevant house or not. Also, the condition has 5 unique values that increase from 1 to 5 based on the state of the house. And as you might guess, street, city, statezip, and country are the nominal ones.
#
# **Types of Data**
#
# * Categorical (gender, blood type, aswers of yes/no questions, satisfaction/condition level etc.)
#
# * Numerical
#     1.   Discrete (finite numbers- # of children/customer/room,physical money, time on a clock etc.)
#     2.   Continuous (infinite numbers- measurements(weight, height), time in general etc.)
#
#
# **Levels of Measurement**
#
# * Qualitative
# a. Nominal (Can not be ordered- gender, blood type, seasons)
# b. Ordinal (Takes values with an order or rank- satisfaction, condition level)
# * Quantitative
# a. Interval (Don't have a true zero- temperature, pH, IQ test etc.)
# b. Ratios (Have a true zero- temperature only in Kelvin, amount, distance, pulse etc.)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline

# %% [markdown]
# **Loading Dataset**
#
#
# Download the dataset from :https://www.kaggle.com/datasets/shree1992/housedata/data
# Copy the path of the dataset and paste it in the command *below*

# %%
dataset_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IAT 360/1/data.csv")

# %% [markdown]
# **Exploring Dataset**

# %%
dataset_2.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
dataset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
#  17  country        4600 non-null   object
# dtypes: float64(4), int64(9), object(5)
# memory usage: 647.0+ KB

# %% [markdown]
# **Handling missing values**
#
# There is no NaN value in our data set, but it would be good to check 0's or 999's for the sake of data consistency. I don't see any irrelevant max values in the describe output but there are some zeros to check.

# %%
dataset_2[dataset_2==0].count()
# Out:
# date                0
# price              49
# bedrooms            2
# bathrooms           2
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       4567
# view             4140
# condition           0
# sqft_above          0
# sqft_basement    2745
# yr_built            0
# yr_renovated     2735
# street              0
# city                0
# statezip            0
# country             0
# dtype: int64

# %% [markdown]
# We have to deal with 49 houses that look free of cost, plus 2 houses each without a bedroom and a bathroom. Since they are few in number, we can remove these values directly from our data set.

# %%
dataset_2 = dataset_2.drop(dataset_2[(dataset_2['price']==0)].index)
dataset_2 = dataset_2.drop(dataset_2[(dataset_2['bedrooms']==0)].index)
dataset_2 = dataset_2.drop(dataset_2[(dataset_2['bathrooms']==0)].index)

# %%
dataset_2.shape
# Out:
# (4549, 18)

# %% [markdown]
# We can see now 4549 samples are left after removing samples with missing data. We can further explore the data and find outliers.
#
# For further exploration see: https://www.kaggle.com/datasets/shree1992/housedata

# %% [markdown]
# ## **Text Data**

# %% [markdown]
# The data is basically a collection of tweets annotated with the emotions behind them. We have three columns tweet_id, sentiment, and content. In "content" we have the raw tweet. In "sentiment" we have the emotion behind the tweet. Refer to the starter notebook for more insights.
#
# The data has 13 different emotion 40000 records.
#
# **Problem**: Finding the emotion for each tweet, also called emotion recognition from Text.

# %% [markdown]
# Importing required Libraries

# %%
import pandas as pd
import seaborn as sns

import re
import nltk
import nltk
from nltk.corpus import stopwords

from nltk.stem.snowball import SnowballStemmer
from wordcloud import WordCloud

# %% [markdown]
# Download the dataset from: https://www.kaggle.com/datasets/pashupatigupta/emotion-detection-from-text/data
#
#
# Loading Dataset

# %%
dataset_3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/IAT 360/2/tweet_emotions.csv')
dataset_3.head()
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...

# %% [markdown]
# Dimensions of the data  : 40,000 samples, with 3 columns

# %%
dataset_3.shape
# Out:
# (40000, 3)

# %% [markdown]
# Data Cleaning and EDA

# %%
dataset_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   40000 non-null  int64
#  1   sentiment  40000 non-null  object
#  2   content    40000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 937.6+ KB

# %%
sns.countplot(x=dataset_3['sentiment'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Text Preprocessing

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = stopwords.words('english')
stemmer = SnowballStemmer('english')

# %%
def clean(text):
    text = text.lower()
    text = re.sub('[^\w\s]', '', text)
    text = [word for word in text.split() if word not in stop_words]
    text = [stemmer.stem(w) for w in text]
    return text

# %%
dataset_3['text'] = dataset_3['content'].apply(lambda x: clean(x))
dataset_3['text'] = dataset_3['text'].apply(lambda x: ' '.join(x))
dataset_3.head()
# Out:
#      tweet_id   sentiment                                            content  \
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...
#
#                                                 text
# 0  tiffanylu know listenin bad habit earlier star...
# 1              layin n bed headach ughhhhwaitin call
# 2                        funer ceremonygloomi friday
# 3                              want hang friend soon
# 4  dannycastillo want trade someon houston ticket...

# %% [markdown]
# Word Cloud

# %%
all_words = ' '.join(word for word in dataset_3['text'])


wordcloud = WordCloud(
    width = 1000,
    height = 600,
    background_color = 'skyblue',
    min_font_size = 10).generate(all_words)
plt.figure(figsize = (10, 6), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# ## **Images Data**

# %% [markdown]
#  Download the data from : https://www.kaggle.com/datasets/saworz/human-faces-with-labels/data
#
#
# There are two folders:
# 1. **Data**
#
#       Contains images of faces
# 2. **Labels**
#
#       Contains bounding boxes (labels) for the images

# %% [markdown]
# Importing required Libraries

# %%
from pathlib import Path
import os
from os import listdir
from os.path import isfile, join
import random as random
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib import patches as mpatches

# %% [markdown]
# Get Data from folders

# %%
data_path= "/content/drive/MyDrive/Colab Notebooks/IAT 360/3/Data"
images_path = "/content/drive/MyDrive/Colab Notebooks/IAT 360/3/Data/Images"
annotations_path="/content/drive/MyDrive/Colab Notebooks/IAT 360/3/Data/Labels"

# %% [markdown]
# Directory Exploration

# %%
def walk_through_dir(dir_path: Path) -> None:
    """Prints dir_path content"""
    for dirpath, dirnames, filenames in os.walk(dir_path):
        print(f"There are {len(dirnames)} folders and {len(filenames)} files in '{dirpath}' folder ")


walk_through_dir(data_path)
# Out:
# There are 2 folders and 0 files in '/content/drive/MyDrive/Colab Notebooks/IAT 360/3/Data' folder
# There are 0 folders and 791 files in '/content/drive/MyDrive/Colab Notebooks/IAT 360/3/Data/Images' folder
# There are 0 folders and 791 files in '/content/drive/MyDrive/Colab Notebooks/IAT 360/3/Data/Labels' folder

# %% [markdown]
# Print some random images and draw bounding boxes to see if they are correct

# %%
def print_random_images(photos: list, n: int = 5, seed=None):
    if n > 10:
        n=10
    if seed:
        rnd.seed(seed)

    for im in range(n):
        random_photo = random.choice(photos)
        random_photo_path = str(images_path) + '/' + str(random_photo)

        with Image.open(random_photo_path) as fd:
            fig, ax = plt.subplots()
            ax.imshow(fd)
            ax.axis(False)
            image_width, image_height = fd.size

        file=random_photo[:random_photo.index(".")] + '.txt'
        annotation_file = annotations_path+"/"+ file
        with open(annotation_file) as f:
            label = f.read()

        labels = label.split(" ")
        labels[4] = labels[4][:-1]
        labels = list(map(float, labels))

        x1, y1, width, height=labels[1:]
        bbox_x = x1*image_width-image_width*width/2
        bbox_y = y1*image_height-image_height*height/2
        bbox_width=width*image_width
        bbox_height=height*image_height

        mpatch=mpatches.Rectangle((bbox_x, bbox_y), bbox_width, bbox_height, linewidth=1, edgecolor='b', facecolor="none", lw=2)
        ax.add_patch(mpatch)
        rx, ry = mpatch.get_xy()
        ax.annotate('face', (rx, ry-2), color='blue', weight='bold', fontsize=12, ha='left', va='baseline')

photos_list = [f for f in listdir(images_path) if isfile(join(images_path, f))]

print_random_images(photos_list)

# %% [markdown]
# ## **Audio Data**

# %% [markdown]
# **Files**
# This portion of the RAVDESS contains 1440 files: 60 trials per actor x 24 actors = 1440. The RAVDESS contains 24 professional actors (12 female, 12 male), vocalizing two lexically-matched statements in a neutral North American accent. Speech emotions includes calm, happy, sad, angry, fearful, surprise, and disgust expressions. Each expression is produced at two levels of emotional intensity (normal, strong), with an additional neutral expression.
#
# **File naming convention**
#
# Each of the 1440 files has a unique filename. The filename consists of a 7-part numerical identifier (e.g., 03-01-06-01-02-01-12.wav). These identifiers define the stimulus characteristics:
#
# **Filename identifiers**
#
# * Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
#
# * Vocal channel (01 = speech, 02 = song).
#
# * Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
#
# * Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
#
# * Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
#
# * Repetition (01 = 1st repetition, 02 = 2nd repetition).
#
# * Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# Filename example: 03-01-06-01-02-01-12.wav
#
# 1. Audio-only (03)
# 2. Speech (01)
# 3. Fearful (06)
# 4. Normal intensity (01)
# 5. Statement "dogs" (02)
# 6. 1st Repetition (01)
# 7. 12th Actor (12) Female, as the actor ID number is even.

# %% [markdown]
# Importing Libraries

# %%
#importing the required libraries

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import librosa.display
import soundfile
import os

from glob import glob

import librosa
import IPython.display as ipd

# %% [markdown]
# Download the dataset from the [audio dataset folder.](https://1sfu-my.sharepoint.com/:f:/g/personal/oyalcin_sfu_ca/ErKIxg5g4rFOlfrAZ352DW4BD1ytBiz1kZLcj5Elk9_1rQ?e=lgUQoi)
#
# ### Load the Dataset and Compute Features
# We have to understand the labelling of the RAVDESS dataset to find the ground truth emotion for each sample.
# Each file is labelled with 7 numbers delimited by a "-".
# Most of the numbers describe metadata about the audio samples such as their format (video and/or audio),
# whether the audio is a song or statement, which of two statements is being read and by which actor.
#
# The third and fourth numbers pertain to the emotional quality of each sample. The third number is in the range of 1-8 with each number representing an emotion.
# The fourth number is either 1 or 2, representing normal (1) or strong (2) emotional intensity.
#
# When you upload your own data, you should be using this convention.
#
# We're going to define a dictionary based on the third number (emotion) and assign an emotion to each number as specified by the RAVDESS dataset:

# %%
audio_files = glob('/content/drive/MyDrive/Colab Notebooks/Audio Data/*/*.wav')

#Playing an audio file using IPython.display
ipd.Audio(audio_files[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Emotions in the RAVDESS dataset
emotions_dict ={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

# %% [markdown]
# Now we're going to load our data and extract the emotion names according to the list we provided above.

# %%
import os, glob

def load_data():
    X,y=[],[]
    count = 0
    for file in glob.glob("/content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_*/*.wav"):
        file_name=os.path.basename(file)
        print(file)
        emotion=emotions_dict[file_name.split("-")[2]]
        print(emotion)
        #features = get_features(file)
        #X.append(features)
        y.append(emotion)
        count += 1
        # '\r' + end='' results in printing over same line
        print('\r' + f' Processed {count}/{1440} audio samples',end=' ')
    # Return arrays to plug into sklearn's cross-validation algorithms
    return np.array(X), np.array(y)

# %% [markdown]
# We will not compute the feature matrix this week, but we will read the emotion labels for the entire dataset.
# We will explain why the X and Y elements are important in the upcoming weeks.

# %%
features, emotions = load_data()
# Out:
# /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-03-02-02-01-01.wav
# happy
#  Processed 1/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-03-02-01-01-01.wav
# happy
#  Processed 2/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-03-02-01-02-01.wav
# happy
#  Processed 3/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-03-02-02-02-01.wav
# happy
#  Processed 4/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-04-02-01-01-01.wav
# sad
#  Processed 5/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-03-01-02-01-01.wav
# happy
#  Processed 6/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-03-01-02-02-01.wav
# happy
#  Processed 7/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-03-01-01-02-01.wav
# happy
#  Processed 8/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-02-02-01-01-01.wav
# calm
#  Processed 9/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-02-01-02-02-01.wav
# calm
#  Processed 10/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-02-02-02-01-01.wav
# calm
#  Processed 11/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-02-02-01-02-01.wav
# calm
#  Processed 12/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-02-01-02-01-01.wav
# calm
#  Processed 13/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-03-01-01-01-01.wav
# happy
#  Processed 14/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-02-01-01-01-01.wav
# calm
#  Processed 15/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-01-01-02-02-01.wav
# neutral
#  Processed 16/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-02-01-01-02-01.wav
# calm
#  Processed 17/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-02-02-02-02-01.wav
# calm
#  Processed 18/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-01-01-02-01-01.wav
# neutral
#  Processed 19/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-01-01-01-02-01.wav
# neutral
#  Processed 20/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-01-01-01-01-01.wav
# neutral
#  Processed 21/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-08-02-02-02-01.wav
# surprised
#  Processed 22/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-08-02-01-02-01.wav
# surprised
#  Processed 23/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-08-02-02-01-01.wav
# surprised
#  Processed 24/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-08-01-02-01-01.wav
# surprised
#  Processed 25/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-08-01-02-02-01.wav
# surprised
#  Processed 26/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-08-02-01-01-01.wav
# surprised
#  Processed 27/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-08-01-01-02-01.wav
# surprised
#  Processed 28/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-08-01-01-01-01.wav
# surprised
#  Processed 29/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-07-02-01-01-01.wav
# disgust
#  Processed 30/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-07-01-02-02-01.wav
# disgust
#  Processed 31/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-07-01-02-01-01.wav
# disgust
#  Processed 32/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-07-02-02-02-01.wav
# disgust
#  Processed 33/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-07-01-01-02-01.wav
# disgust
#  Processed 34/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-07-01-01-01-01.wav
# disgust
#  Processed 35/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-06-02-02-01-01.wav
# fearful
#  Processed 36/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-06-02-01-02-01.wav
# fearful
#  Processed 37/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-06-02-02-02-01.wav
# fearful
#  Processed 38/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-07-02-02-01-01.wav
# disgust
#  Processed 39/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-06-02-01-01-01.wav
# fearful
#  Processed 40/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-07-02-01-02-01.wav
# disgust
#  Processed 41/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-05-02-02-02-01.wav
# angry
#  Processed 42/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-05-02-01-01-01.wav
# angry
#  Processed 43/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-05-02-02-01-01.wav
# angry
#  Processed 44/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-05-02-01-02-01.wav
# angry
#  Processed 45/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-06-01-02-02-01.wav
# fearful
#  Processed 46/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-06-01-02-01-01.wav
# fearful
#  Processed 47/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-05-01-02-02-01.wav
# angry
#  Processed 48/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-05-01-01-01-01.wav
# angry
#  Processed 49/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-05-01-01-02-01.wav
# angry
#  Processed 50/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-05-01-02-01-01.wav
# angry
#  Processed 51/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-06-01-01-02-01.wav
# fearful
#  Processed 52/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-06-01-01-01-01.wav
# fearful
#  Processed 53/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-04-02-02-02-01.wav
# sad
#  Processed 54/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-04-02-02-01-01.wav
# sad
#  Processed 55/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-04-01-02-02-01.wav
# sad
#  Processed 56/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-04-01-02-01-01.wav
# sad
#  Processed 57/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-04-01-01-01-01.wav
# sad
#  Processed 58/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-04-01-01-02-01.wav
# sad
#  Processed 59/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_01/03-01-04-02-01-02-01.wav
# sad
#  Processed 60/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-04-01-02-01-02.wav
# sad
#  Processed 61/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-03-02-02-01-02.wav
# happy
#  Processed 62/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-03-01-02-01-02.wav
# happy
#  Processed 63/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-03-02-01-02-02.wav
# happy
#  Processed 64/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-03-01-02-02-02.wav
# happy
#  Processed 65/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-03-02-01-01-02.wav
# happy
#  Processed 66/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-04-01-01-02-02.wav
# sad
#  Processed 67/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-04-01-01-01-02.wav
# sad
#  Processed 68/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-03-01-01-01-02.wav
# happy
#  Processed 69/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-02-02-02-01-02.wav
# calm
#  Processed 70/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-03-01-01-02-02.wav
# happy
#  Processed 71/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-03-02-02-02-02.wav
# happy
#  Processed 72/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-02-02-02-02-02.wav
# calm
#  Processed 73/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-02-02-01-02-02.wav
# calm
#  Processed 74/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-02-01-02-01-02.wav
# calm
#  Processed 75/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-02-01-01-01-02.wav
# calm
#  Processed 76/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-02-01-01-02-02.wav
# calm
#  Processed 77/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-01-01-02-02-02.wav
# neutral
#  Processed 78/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-02-02-01-01-02.wav
# calm
#  Processed 79/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-01-01-01-01-02.wav
# neutral
#  Processed 80/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-01-01-01-02-02.wav
# neutral
#  Processed 81/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-01-01-02-01-02.wav
# neutral
#  Processed 82/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-02-01-02-02-02.wav
# calm
#  Processed 83/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-08-02-01-02-02.wav
# surprised
#  Processed 84/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-08-01-01-02-02.wav
# surprised
#  Processed 85/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-08-01-02-02-02.wav
# surprised
#  Processed 86/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-08-02-02-02-02.wav
# surprised
#  Processed 87/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-08-01-02-01-02.wav
# surprised
#  Processed 88/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-08-02-01-01-02.wav
# surprised
#  Processed 89/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-07-02-02-02-02.wav
# disgust
#  Processed 90/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-07-02-02-01-02.wav
# disgust
#  Processed 91/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-08-01-01-01-02.wav
# surprised
#  Processed 92/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-08-02-02-01-02.wav
# surprised
#  Processed 93/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-07-02-01-02-02.wav
# disgust
#  Processed 94/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-07-02-01-01-02.wav
# disgust
#  Processed 95/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-07-01-01-01-02.wav
# disgust
#  Processed 96/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-06-02-01-02-02.wav
# fearful
#  Processed 97/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-06-02-02-02-02.wav
# fearful
#  Processed 98/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-06-02-02-01-02.wav
# fearful
#  Processed 99/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-07-01-02-02-02.wav
# disgust
#  Processed 100/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-06-01-01-02-02.wav
# fearful
#  Processed 101/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-06-01-02-01-02.wav
# fearful
#  Processed 102/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-06-01-02-02-02.wav
# fearful
#  Processed 103/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-06-02-01-01-02.wav
# fearful
#  Processed 104/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-07-01-02-01-02.wav
# disgust
#  Processed 105/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-07-01-01-02-02.wav
# disgust
#  Processed 106/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-06-01-01-01-02.wav
# fearful
#  Processed 107/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-05-02-02-02-02.wav
# angry
#  Processed 108/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-05-01-02-02-02.wav
# angry
#  Processed 109/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-05-01-01-02-02.wav
# angry
#  Processed 110/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-05-01-02-01-02.wav
# angry
#  Processed 111/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-05-01-01-01-02.wav
# angry
#  Processed 112/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-04-02-01-01-02.wav
# sad
#  Processed 113/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-04-02-01-02-02.wav
# sad
#  Processed 114/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-04-02-02-01-02.wav
# sad
#  Processed 115/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-04-02-02-02-02.wav
# sad
#  Processed 116/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-05-02-02-01-02.wav
# angry
#  Processed 117/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-05-02-01-02-02.wav
# angry
#  Processed 118/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-05-02-01-01-02.wav
# angry
#  Processed 119/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_02/03-01-04-01-02-02-02.wav
# sad
#  Processed 120/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-03-02-02-02-03.wav
# happy
#  Processed 121/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-05-01-01-01-03.wav
# angry
#  Processed 122/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-03-02-02-01-03.wav
# happy
#  Processed 123/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-03-01-02-02-03.wav
# happy
#  Processed 124/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-03-02-01-02-03.wav
# happy
#  Processed 125/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-03-01-02-01-03.wav
# happy
#  Processed 126/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-02-02-02-02-03.wav
# calm
#  Processed 127/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-03-01-01-02-03.wav
# happy
#  Processed 128/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-03-01-01-01-03.wav
# happy
#  Processed 129/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-02-02-01-01-03.wav
# calm
#  Processed 130/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-02-02-01-02-03.wav
# calm
#  Processed 131/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-02-02-02-01-03.wav
# calm
#  Processed 132/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-03-02-01-01-03.wav
# happy
#  Processed 133/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-02-01-02-01-03.wav
# calm
#  Processed 134/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-02-01-02-02-03.wav
# calm
#  Processed 135/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-01-01-02-01-03.wav
# neutral
#  Processed 136/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-01-01-01-01-03.wav
# neutral
#  Processed 137/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-01-01-01-02-03.wav
# neutral
#  Processed 138/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-02-01-01-02-03.wav
# calm
#  Processed 139/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-02-01-01-01-03.wav
# calm
#  Processed 140/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-01-01-02-02-03.wav
# neutral
#  Processed 141/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-08-02-02-02-03.wav
# surprised
#  Processed 142/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-08-02-01-02-03.wav
# surprised
#  Processed 143/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-08-02-02-01-03.wav
# surprised
#  Processed 144/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-08-01-01-02-03.wav
# surprised
#  Processed 145/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-08-01-01-01-03.wav
# surprised
#  Processed 146/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-07-02-02-02-03.wav
# disgust
#  Processed 147/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-08-02-01-01-03.wav
# surprised
#  Processed 148/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-08-01-02-02-03.wav
# surprised
#  Processed 149/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-07-02-02-01-03.wav
# disgust
#  Processed 150/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-07-02-01-02-03.wav
# disgust
#  Processed 151/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-07-01-02-01-03.wav
# disgust
#  Processed 152/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-07-01-02-02-03.wav
# disgust
#  Processed 153/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-07-02-01-01-03.wav
# disgust
#  Processed 154/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-08-01-02-01-03.wav
# surprised
#  Processed 155/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-07-01-01-02-03.wav
# disgust
#  Processed 156/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-07-01-01-01-03.wav
# disgust
#  Processed 157/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-06-02-01-01-03.wav
# fearful
#  Processed 158/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-06-01-02-01-03.wav
# fearful
#  Processed 159/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-06-01-01-02-03.wav
# fearful
#  Processed 160/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-06-01-02-02-03.wav
# fearful
#  Processed 161/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-06-01-01-01-03.wav
# fearful
#  Processed 162/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-06-02-02-02-03.wav
# fearful
#  Processed 163/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-05-02-02-02-03.wav
# angry
#  Processed 164/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-05-02-01-02-03.wav
# angry
#  Processed 165/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-05-02-02-01-03.wav
# angry
#  Processed 166/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-06-02-02-01-03.wav
# fearful
#  Processed 167/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-06-02-01-02-03.wav
# fearful
#  Processed 168/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-05-02-01-01-03.wav
# angry
#  Processed 169/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-05-01-02-02-03.wav
# angry
#  Processed 170/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-04-02-01-02-03.wav
# sad
#  Processed 171/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-04-02-01-01-03.wav
# sad
#  Processed 172/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-04-02-02-02-03.wav
# sad
#  Processed 173/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-04-02-02-01-03.wav
# sad
#  Processed 174/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-05-01-02-01-03.wav
# angry
#  Processed 175/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-04-01-02-01-03.wav
# sad
#  Processed 176/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-04-01-01-01-03.wav
# sad
#  Processed 177/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-04-01-01-02-03.wav
# sad
#  Processed 178/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-04-01-02-02-03.wav
# sad
#  Processed 179/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_03/03-01-05-01-01-02-03.wav
# angry
#  Processed 180/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-04-02-02-01-04.wav
# sad
#  Processed 181/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-03-02-01-02-04.wav
# happy
#  Processed 182/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-03-02-02-02-04.wav
# happy
#  Processed 183/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-03-02-02-01-04.wav
# happy
#  Processed 184/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-04-01-01-01-04.wav
# sad
#  Processed 185/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-03-02-01-01-04.wav
# happy
#  Processed 186/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-04-02-01-02-04.wav
# sad
#  Processed 187/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-03-01-02-02-04.wav
# happy
#  Processed 188/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-02-02-02-02-04.wav
# calm
#  Processed 189/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-02-02-01-02-04.wav
# calm
#  Processed 190/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-02-02-01-01-04.wav
# calm
#  Processed 191/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-02-02-02-01-04.wav
# calm
#  Processed 192/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-03-01-02-01-04.wav
# happy
#  Processed 193/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-03-01-01-02-04.wav
# happy
#  Processed 194/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-02-01-01-02-04.wav
# calm
#  Processed 195/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-02-01-02-01-04.wav
# calm
#  Processed 196/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-02-01-02-02-04.wav
# calm
#  Processed 197/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-02-01-01-01-04.wav
# calm
#  Processed 198/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-03-01-01-01-04.wav
# happy
#  Processed 199/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-01-01-02-02-04.wav
# neutral
#  Processed 200/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-01-01-02-01-04.wav
# neutral
#  Processed 201/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-01-01-01-02-04.wav
# neutral
#  Processed 202/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-01-01-01-01-04.wav
# neutral
#  Processed 203/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-08-02-02-02-04.wav
# surprised
#  Processed 204/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-08-02-01-01-04.wav
# surprised
#  Processed 205/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-08-01-02-02-04.wav
# surprised
#  Processed 206/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-08-02-01-02-04.wav
# surprised
#  Processed 207/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-08-02-02-01-04.wav
# surprised
#  Processed 208/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-08-01-02-01-04.wav
# surprised
#  Processed 209/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-08-01-01-02-04.wav
# surprised
#  Processed 210/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-07-02-01-02-04.wav
# disgust
#  Processed 211/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-07-01-02-02-04.wav
# disgust
#  Processed 212/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-07-01-01-01-04.wav
# disgust
#  Processed 213/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-08-01-01-01-04.wav
# surprised
#  Processed 214/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-07-02-01-01-04.wav
# disgust
#  Processed 215/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-06-02-02-01-04.wav
# fearful
#  Processed 216/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-07-01-01-02-04.wav
# disgust
#  Processed 217/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-06-02-02-02-04.wav
# fearful
#  Processed 218/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-07-01-02-01-04.wav
# disgust
#  Processed 219/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-07-02-02-02-04.wav
# disgust
#  Processed 220/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-06-02-01-02-04.wav
# fearful
#  Processed 221/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-07-02-02-01-04.wav
# disgust
#  Processed 222/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-06-01-01-02-04.wav
# fearful
#  Processed 223/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-05-02-01-02-04.wav
# angry
#  Processed 224/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-05-02-02-02-04.wav
# angry
#  Processed 225/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-06-01-01-01-04.wav
# fearful
#  Processed 226/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-06-02-01-01-04.wav
# fearful
#  Processed 227/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-06-01-02-02-04.wav
# fearful
#  Processed 228/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-05-01-02-01-04.wav
# angry
#  Processed 229/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-05-01-02-02-04.wav
# angry
#  Processed 230/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-05-02-01-01-04.wav
# angry
#  Processed 231/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-05-02-02-01-04.wav
# angry
#  Processed 232/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-06-01-02-01-04.wav
# fearful
#  Processed 233/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-05-01-01-02-04.wav
# angry
#  Processed 234/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-05-01-01-01-04.wav
# angry
#  Processed 235/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-04-02-02-02-04.wav
# sad
#  Processed 236/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-04-02-01-01-04.wav
# sad
#  Processed 237/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-04-01-02-02-04.wav
# sad
#  Processed 238/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-04-01-01-02-04.wav
# sad
#  Processed 239/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_04/03-01-04-01-02-01-04.wav
# sad
#  Processed 240/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-04-02-01-02-05.wav
# sad
#  Processed 241/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-04-02-01-01-05.wav
# sad
#  Processed 242/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-03-02-02-01-05.wav
# happy
#  Processed 243/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-03-02-02-02-05.wav
# happy
#  Processed 244/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-04-01-01-01-05.wav
# sad
#  Processed 245/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-03-02-01-01-05.wav
# happy
#  Processed 246/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-04-01-02-02-05.wav
# sad
#  Processed 247/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-03-01-02-02-05.wav
# happy
#  Processed 248/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-03-01-02-01-05.wav
# happy
#  Processed 249/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-03-01-01-02-05.wav
# happy
#  Processed 250/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-03-02-01-02-05.wav
# happy
#  Processed 251/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-04-01-02-01-05.wav
# sad
#  Processed 252/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-03-01-01-01-05.wav
# happy
#  Processed 253/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-04-01-01-02-05.wav
# sad
#  Processed 254/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-02-02-02-02-05.wav
# calm
#  Processed 255/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-02-02-01-01-05.wav
# calm
#  Processed 256/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-02-01-01-02-05.wav
# calm
#  Processed 257/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-02-01-02-02-05.wav
# calm
#  Processed 258/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-02-01-02-01-05.wav
# calm
#  Processed 259/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-02-02-02-01-05.wav
# calm
#  Processed 260/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-01-01-02-01-05.wav
# neutral
#  Processed 261/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-01-01-02-02-05.wav
# neutral
#  Processed 262/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-01-01-01-02-05.wav
# neutral
#  Processed 263/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-02-01-01-01-05.wav
# calm
#  Processed 264/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-02-02-01-02-05.wav
# calm
#  Processed 265/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-01-01-01-01-05.wav
# neutral
#  Processed 266/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-08-02-02-02-05.wav
# surprised
#  Processed 267/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-08-01-02-02-05.wav
# surprised
#  Processed 268/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-08-02-01-01-05.wav
# surprised
#  Processed 269/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-08-02-01-02-05.wav
# surprised
#  Processed 270/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-08-01-01-01-05.wav
# surprised
#  Processed 271/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-08-01-01-02-05.wav
# surprised
#  Processed 272/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-08-01-02-01-05.wav
# surprised
#  Processed 273/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-08-02-02-01-05.wav
# surprised
#  Processed 274/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-07-02-02-02-05.wav
# disgust
#  Processed 275/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-07-02-02-01-05.wav
# disgust
#  Processed 276/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-07-02-01-02-05.wav
# disgust
#  Processed 277/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-07-01-01-01-05.wav
# disgust
#  Processed 278/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-06-02-02-02-05.wav
# fearful
#  Processed 279/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-07-01-01-02-05.wav
# disgust
#  Processed 280/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-07-01-02-01-05.wav
# disgust
#  Processed 281/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-07-02-01-01-05.wav
# disgust
#  Processed 282/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-06-02-01-01-05.wav
# fearful
#  Processed 283/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-06-02-01-02-05.wav
# fearful
#  Processed 284/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-06-01-02-02-05.wav
# fearful
#  Processed 285/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-06-02-02-01-05.wav
# fearful
#  Processed 286/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-07-01-02-02-05.wav
# disgust
#  Processed 287/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-06-01-02-01-05.wav
# fearful
#  Processed 288/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-06-01-01-02-05.wav
# fearful
#  Processed 289/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-05-02-01-02-05.wav
# angry
#  Processed 290/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-05-01-02-02-05.wav
# angry
#  Processed 291/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-05-02-01-01-05.wav
# angry
#  Processed 292/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-05-01-02-01-05.wav
# angry
#  Processed 293/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-06-01-01-01-05.wav
# fearful
#  Processed 294/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-05-01-01-02-05.wav
# angry
#  Processed 295/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-04-02-02-02-05.wav
# sad
#  Processed 296/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-04-02-02-01-05.wav
# sad
#  Processed 297/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-05-01-01-01-05.wav
# angry
#  Processed 298/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-05-02-02-02-05.wav
# angry
#  Processed 299/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_05/03-01-05-02-02-01-05.wav
# angry
#  Processed 300/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-05-02-01-01-06.wav
# angry
#  Processed 301/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-04-02-02-02-06.wav
# sad
#  Processed 302/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-04-01-02-02-06.wav
# sad
#  Processed 303/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-04-02-01-01-06.wav
# sad
#  Processed 304/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-04-02-02-01-06.wav
# sad
#  Processed 305/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-05-01-02-02-06.wav
# angry
#  Processed 306/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-04-01-02-01-06.wav
# sad
#  Processed 307/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-04-01-01-02-06.wav
# sad
#  Processed 308/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-03-01-01-01-06.wav
# happy
#  Processed 309/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-03-01-02-01-06.wav
# happy
#  Processed 310/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-03-01-02-02-06.wav
# happy
#  Processed 311/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-03-02-01-02-06.wav
# happy
#  Processed 312/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-03-02-01-01-06.wav
# happy
#  Processed 313/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-04-01-01-01-06.wav
# sad
#  Processed 314/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-03-02-02-02-06.wav
# happy
#  Processed 315/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-02-02-02-01-06.wav
# calm
#  Processed 316/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-02-02-02-02-06.wav
# calm
#  Processed 317/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-03-01-01-02-06.wav
# happy
#  Processed 318/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-03-02-02-01-06.wav
# happy
#  Processed 319/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-02-02-01-02-06.wav
# calm
#  Processed 320/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-02-02-01-01-06.wav
# calm
#  Processed 321/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-02-01-02-02-06.wav
# calm
#  Processed 322/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-02-01-01-01-06.wav
# calm
#  Processed 323/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-01-01-02-01-06.wav
# neutral
#  Processed 324/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-01-01-02-02-06.wav
# neutral
#  Processed 325/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-01-01-01-02-06.wav
# neutral
#  Processed 326/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-01-01-01-01-06.wav
# neutral
#  Processed 327/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-02-01-02-01-06.wav
# calm
#  Processed 328/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-02-01-01-02-06.wav
# calm
#  Processed 329/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-08-02-02-02-06.wav
# surprised
#  Processed 330/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-08-02-01-01-06.wav
# surprised
#  Processed 331/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-07-02-02-02-06.wav
# disgust
#  Processed 332/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-08-01-02-02-06.wav
# surprised
#  Processed 333/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-08-01-02-01-06.wav
# surprised
#  Processed 334/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-08-02-02-01-06.wav
# surprised
#  Processed 335/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-08-01-01-01-06.wav
# surprised
#  Processed 336/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-07-02-01-02-06.wav
# disgust
#  Processed 337/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-07-02-02-01-06.wav
# disgust
#  Processed 338/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-08-01-01-02-06.wav
# surprised
#  Processed 339/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-08-02-01-02-06.wav
# surprised
#  Processed 340/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-07-01-02-02-06.wav
# disgust
#  Processed 341/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-07-02-01-01-06.wav
# disgust
#  Processed 342/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-06-01-02-02-06.wav
# fearful
#  Processed 343/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-06-02-02-01-06.wav
# fearful
#  Processed 344/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-06-02-02-02-06.wav
# fearful
#  Processed 345/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-06-02-01-02-06.wav
# fearful
#  Processed 346/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-07-01-02-01-06.wav
# disgust
#  Processed 347/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-07-01-01-02-06.wav
# disgust
#  Processed 348/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-06-01-01-02-06.wav
# fearful
#  Processed 349/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-06-01-01-01-06.wav
# fearful
#  Processed 350/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-06-01-02-01-06.wav
# fearful
#  Processed 351/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-06-02-01-01-06.wav
# fearful
#  Processed 352/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-07-01-01-01-06.wav
# disgust
#  Processed 353/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-05-02-02-01-06.wav
# angry
#  Processed 354/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-05-02-02-02-06.wav
# angry
#  Processed 355/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-05-01-02-01-06.wav
# angry
#  Processed 356/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-05-01-01-02-06.wav
# angry
#  Processed 357/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-05-01-01-01-06.wav
# angry
#  Processed 358/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-04-02-01-02-06.wav
# sad
#  Processed 359/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_06/03-01-05-02-01-02-06.wav
# angry
#  Processed 360/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-04-02-02-01-07.wav
# sad
#  Processed 361/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-04-01-02-02-07.wav
# sad
#  Processed 362/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-04-02-01-02-07.wav
# sad
#  Processed 363/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-04-02-01-01-07.wav
# sad
#  Processed 364/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-05-01-01-02-07.wav
# angry
#  Processed 365/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-05-01-01-01-07.wav
# angry
#  Processed 366/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-04-01-01-02-07.wav
# sad
#  Processed 367/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-04-01-01-01-07.wav
# sad
#  Processed 368/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-03-02-02-02-07.wav
# happy
#  Processed 369/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-04-01-02-01-07.wav
# sad
#  Processed 370/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-04-02-02-02-07.wav
# sad
#  Processed 371/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-03-02-02-01-07.wav
# happy
#  Processed 372/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-03-02-01-02-07.wav
# happy
#  Processed 373/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-03-01-01-02-07.wav
# happy
#  Processed 374/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-02-02-02-02-07.wav
# calm
#  Processed 375/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-02-02-02-01-07.wav
# calm
#  Processed 376/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-03-01-01-01-07.wav
# happy
#  Processed 377/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-03-02-01-01-07.wav
# happy
#  Processed 378/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-02-01-02-01-07.wav
# calm
#  Processed 379/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-02-02-01-01-07.wav
# calm
#  Processed 380/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-02-01-02-02-07.wav
# calm
#  Processed 381/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-02-02-01-02-07.wav
# calm
#  Processed 382/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-03-01-02-02-07.wav
# happy
#  Processed 383/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-02-01-01-02-07.wav
# calm
#  Processed 384/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-03-01-02-01-07.wav
# happy
#  Processed 385/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_07/03-01-02-01-01-01-07.wav
# calm
# ...
# sad
#  Processed 1321/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-03-02-01-02-23.wav
# happy
#  Processed 1322/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-03-01-01-02-23.wav
# happy
#  Processed 1323/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-03-01-01-01-23.wav
# happy
#  Processed 1324/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-02-02-02-01-23.wav
# calm
#  Processed 1325/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-02-02-02-02-23.wav
# calm
#  Processed 1326/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-02-02-01-02-23.wav
# calm
#  Processed 1327/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-03-02-01-01-23.wav
# happy
#  Processed 1328/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-03-01-02-02-23.wav
# happy
#  Processed 1329/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-02-01-02-01-23.wav
# calm
#  Processed 1330/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-02-01-02-02-23.wav
# calm
#  Processed 1331/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-02-02-01-01-23.wav
# calm
#  Processed 1332/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-02-01-01-02-23.wav
# calm
#  Processed 1333/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-03-01-02-01-23.wav
# happy
#  Processed 1334/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-01-01-01-01-23.wav
# neutral
#  Processed 1335/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-02-01-01-01-23.wav
# calm
#  Processed 1336/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-01-01-02-02-23.wav
# neutral
#  Processed 1337/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-01-01-02-01-23.wav
# neutral
#  Processed 1338/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-01-01-01-02-23.wav
# neutral
#  Processed 1339/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-08-02-01-02-23.wav
# surprised
#  Processed 1340/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-08-02-02-02-23.wav
# surprised
#  Processed 1341/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-08-02-02-01-23.wav
# surprised
#  Processed 1342/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-08-02-01-01-23.wav
# surprised
#  Processed 1343/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-08-01-02-02-23.wav
# surprised
#  Processed 1344/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-07-02-02-01-23.wav
# disgust
#  Processed 1345/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-07-02-01-01-23.wav
# disgust
#  Processed 1346/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-07-02-01-02-23.wav
# disgust
#  Processed 1347/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-07-02-02-02-23.wav
# disgust
#  Processed 1348/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-07-01-01-02-23.wav
# disgust
#  Processed 1349/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-06-02-02-02-23.wav
# fearful
#  Processed 1350/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-07-01-02-01-23.wav
# disgust
#  Processed 1351/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-08-01-02-01-23.wav
# surprised
#  Processed 1352/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-08-01-01-02-23.wav
# surprised
#  Processed 1353/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-07-01-02-02-23.wav
# disgust
#  Processed 1354/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-08-01-01-01-23.wav
# surprised
#  Processed 1355/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-07-01-01-01-23.wav
# disgust
#  Processed 1356/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-06-02-02-01-23.wav
# fearful
#  Processed 1357/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-06-01-02-01-23.wav
# fearful
#  Processed 1358/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-06-01-01-01-23.wav
# fearful
#  Processed 1359/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-06-01-02-02-23.wav
# fearful
#  Processed 1360/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-06-01-01-02-23.wav
# fearful
#  Processed 1361/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-06-02-01-02-23.wav
# fearful
#  Processed 1362/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-05-02-02-01-23.wav
# angry
#  Processed 1363/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-05-02-01-01-23.wav
# angry
#  Processed 1364/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-05-02-01-02-23.wav
# angry
#  Processed 1365/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-05-02-02-02-23.wav
# angry
#  Processed 1366/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-06-02-01-01-23.wav
# fearful
#  Processed 1367/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-05-01-02-01-23.wav
# angry
#  Processed 1368/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-05-01-02-02-23.wav
# angry
#  Processed 1369/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-05-01-01-02-23.wav
# angry
#  Processed 1370/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-04-01-02-02-23.wav
# sad
#  Processed 1371/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-04-02-01-02-23.wav
# sad
#  Processed 1372/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-04-02-01-01-23.wav
# sad
#  Processed 1373/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-05-01-01-01-23.wav
# angry
#  Processed 1374/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-04-02-02-01-23.wav
# sad
#  Processed 1375/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-03-02-02-02-23.wav
# happy
#  Processed 1376/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-04-01-01-02-23.wav
# sad
#  Processed 1377/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-04-01-01-01-23.wav
# sad
#  Processed 1378/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_23/03-01-04-01-02-01-23.wav
# sad
#  Processed 1379/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-04-01-02-01-24.wav
# sad
#  Processed 1380/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-04-01-01-01-24.wav
# sad
#  Processed 1381/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-03-02-02-02-24.wav
# happy
#  Processed 1382/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-04-01-01-02-24.wav
# sad
#  Processed 1383/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-04-02-01-02-24.wav
# sad
#  Processed 1384/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-04-02-01-01-24.wav
# sad
#  Processed 1385/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-03-02-01-01-24.wav
# happy
#  Processed 1386/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-03-01-02-02-24.wav
# happy
#  Processed 1387/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-03-02-01-02-24.wav
# happy
#  Processed 1388/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-03-02-02-01-24.wav
# happy
#  Processed 1389/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-03-01-02-01-24.wav
# happy
#  Processed 1390/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-04-01-02-02-24.wav
# sad
#  Processed 1391/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-02-02-01-02-24.wav
# calm
#  Processed 1392/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-02-01-02-01-24.wav
# calm
#  Processed 1393/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-02-01-02-02-24.wav
# calm
#  Processed 1394/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-02-02-01-01-24.wav
# calm
#  Processed 1395/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-03-01-01-02-24.wav
# happy
#  Processed 1396/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-03-01-01-01-24.wav
# happy
#  Processed 1397/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-02-02-02-02-24.wav
# calm
#  Processed 1398/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-01-01-02-02-24.wav
# neutral
#  Processed 1399/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-01-01-01-02-24.wav
# neutral
#  Processed 1400/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-02-01-01-01-24.wav
# calm
#  Processed 1401/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-02-01-01-02-24.wav
# calm
#  Processed 1402/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-01-01-02-01-24.wav
# neutral
#  Processed 1403/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-02-02-02-01-24.wav
# calm
#  Processed 1404/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-01-01-01-01-24.wav
# neutral
#  Processed 1405/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-04-02-02-01-24.wav
# sad
#  Processed 1406/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-08-02-02-01-24.wav
# surprised
#  Processed 1407/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-08-02-02-02-24.wav
# surprised
#  Processed 1408/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-08-02-01-02-24.wav
# surprised
#  Processed 1409/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-08-01-02-01-24.wav
# surprised
#  Processed 1410/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-08-02-01-01-24.wav
# surprised
#  Processed 1411/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-08-01-01-02-24.wav
# surprised
#  Processed 1412/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-08-01-02-02-24.wav
# surprised
#  Processed 1413/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-08-01-01-01-24.wav
# surprised
#  Processed 1414/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-07-02-01-01-24.wav
# disgust
#  Processed 1415/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-07-01-01-02-24.wav
# disgust
#  Processed 1416/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-07-01-02-01-24.wav
# disgust
#  Processed 1417/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-07-01-02-02-24.wav
# disgust
#  Processed 1418/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-07-02-02-02-24.wav
# disgust
#  Processed 1419/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-07-02-02-01-24.wav
# disgust
#  Processed 1420/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-07-01-01-01-24.wav
# disgust
#  Processed 1421/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-06-02-01-01-24.wav
# fearful
#  Processed 1422/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-06-02-02-01-24.wav
# fearful
#  Processed 1423/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-06-02-02-02-24.wav
# fearful
#  Processed 1424/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-07-02-01-02-24.wav
# disgust
#  Processed 1425/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-06-02-01-02-24.wav
# fearful
#  Processed 1426/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-06-01-02-02-24.wav
# fearful
#  Processed 1427/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-05-02-02-02-24.wav
# angry
#  Processed 1428/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-06-01-02-01-24.wav
# fearful
#  Processed 1429/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-05-01-02-02-24.wav
# angry
#  Processed 1430/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-05-02-01-01-24.wav
# angry
#  Processed 1431/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-05-02-02-01-24.wav
# angry
#  Processed 1432/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-05-02-01-02-24.wav
# angry
#  Processed 1433/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-05-01-01-01-24.wav
# angry
#  Processed 1434/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-05-01-01-02-24.wav
# angry
#  Processed 1435/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-05-01-02-01-24.wav
# angry
#  Processed 1436/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-06-01-01-02-24.wav
# fearful
#  Processed 1437/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-06-01-01-01-24.wav
# fearful
#  Processed 1438/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_24/03-01-04-02-02-02-24.wav
# sad
#  Processed 1439/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_00/03-01-07-01-02-01-00.wav
# disgust
#  Processed 1440/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_00/03-01-02-01-02-01-00.wav
# calm
#  Processed 1441/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_00/03-01-01-01-02-01-00.wav
# neutral
#  Processed 1442/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_00/03-01-05-01-02-01-00.wav
# angry
#  Processed 1443/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_00/03-01-03-01-02-01-00.wav
# happy
#  Processed 1444/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_00/03-01-06-01-02-01-00.wav
# fearful
#  Processed 1445/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_00/03-01-08-01-02-01-00.wav
# surprised
#  Processed 1446/1440 audio samples /content/drive/MyDrive/Colab Notebooks/Audio Data/Actor_00/03-01-04-01-02-01-00.wav
# sad
#  Processed 1447/1440 audio samples

# %% [markdown]
# Let's now see the class balance of our dataset, it is important to have a balanced dataset for ML models.

# %%
# plot emotions
plt.figure(figsize=(35,4))
plt.subplot(1,3,1)
#np.unique returns ordered list of unique elements and count of each element
emotion_list, count = np.unique(emotions, return_counts=True)
print(emotion_list)
plt.bar(x=range(8), height=count)
plt.xticks(ticks=range(8), labels = [emotion for emotion in emotion_list],fontsize=10)
plt.xlabel('Emotion')
plt.tick_params(labelsize=16)
plt.ylabel('Number of Samples')
plt.show()
# Out:
# ['angry' 'calm' 'disgust' 'fearful' 'happy' 'neutral' 'sad' 'surprised']

# %% [markdown]
# **Great, the classes appear to be balanced. That makes the task easier.** All emotions _except_ the neutral class have a "strong" intensity so there are half as many neutral samples. That might have an impact.
#
# We will continue working on this dataset in the upcoming weeks, so save your work!
